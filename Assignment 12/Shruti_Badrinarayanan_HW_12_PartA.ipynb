# %% [markdown]
# # Homework 12 - Part A
# ## Deep Learning Technologies
# ### Shruti Badrinarayanan - 016768141
#
# [Github Link](https://github.com/shruti-badri-14/Deep-Learning-Homework/tree/main/Assignment%2012)

# %%
# !pip install langchain
# !pip install PyPDF2
# !pip install sentence_transformers
# !pip install llama-cpp-python
# !pip install huggingface_hub
# !pip install faiss-cpu

# %%
# !pip install accelerate==0.21.0 transformers==4.31.0 tokenizers==0.13.3
# !pip install bitsandbytes==0.40.0 einops==0.6.1
# !pip install xformers==0.0.22.post7
# !pip install langchain==0.1.4
# !pip install faiss-gpu==1.7.1.post3
# !pip install sentence_transformers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Load the PDF using PdfReader

# %%
# Read code file (saved as pdf)
from PyPDF2 import PdfReader
reader = PdfReader('/content/drive/MyDrive/Deep Learning/Assignments/Assignment 12/Weather_Data_Fetcher.pdf')

# %%
reader

# %%
# read data from the file and put them into a variable called raw_text
raw_text = ''
for i, page in enumerate(reader.pages):
    text = page.extract_text()
    if text:
        raw_text += text

# %%
raw_text
# Out:
# 'import\nimport\n \nrequests\nrequests\ndef\ndef\n \nget_weather\n(\napi_key\n,\n \ncity\n):\n    \n"""\n    Fetches the current weather data for the specified city using OpenWeatherMap API.\n    Parameters:\n    - api_key (str): Your API key for OpenWeatherMap.\n    - city (str): The city name for which weather data is to be fetched.\n    Returns:\n    - dict: A dictionary containing weather data if successful, None otherwise.\n    """\n    \nurl\n \n=\n \nf\n"http://api.openweathermap.org/data/2.5/weather?q={city}&appid=\n{api_key}&units=metric"\n    \ntry\ntry\n:\n        \nresponse\n \n=\n \nrequests\n.\nget\n(\nurl\n)\n        \nresponse\n.\nraise_for_status\n()\n  \n# Raises an HTTPError for bad responses\n        \ndata\n \n=\n \nresponse\n.\njson\n()\n        \nweather_data\n \n=\n \n{\n            \n\'temperature\'\n:\n \ndata\n[\n\'main\'\n][\n\'temp\'\n],\n            \n\'weather\'\n:\n \ndata\n[\n\'weather\'\n][\n0\n][\n\'description\'\n],\n            \n\'humidity\'\n:\n \ndata\n[\n\'main\'\n][\n\'humidity\'\n]\n        \n}\n        \nreturn\nreturn\n \nweather_data\n    \nexcept\nexcept\n \nrequests\n.\nRequestException\n \nas\nas\n \ne\n:\n        \nprint\nprint\n(\nf\n"An error occurred: {e}"\n)\n        \nreturn\nreturn\n \nNone\ndef\ndef\n \nmain\n():\n    \napi_key\n \n=\n \ninput\n(\n"Enter your OpenWeatherMap API Key: "\n)\n    \ncity\n \n=\n \ninput\n(\n"Enter the city name: "\n)\n    \nweather\n \n=\n \nget_weather\n(\napi_key\n,\n \ncity\n)\n    \nif\nif\n \nweather\n:\n        \nprint\nprint\n(\nf\n"Current Temperature in {city}: {weather[\'temperature\']}Â°C"\n)\n        \nprint\nprint\n(\nf\n"Weather: {weather[\'weather\']}"\n)\n        \nprint\nprint\n(\nf\n"Humidity: {weather[\'humidity\']}%"\n)\n    \nelse\nelse\n:\n        \nprint\nprint\n(\n"Failed to get weather data."\n)\nif\nif\n \n__name__\n \n==\n \n"__main__"\n:\n    \nmain\n()'

# %%
raw_text[:100]
# Out:
# 'import\nimport\n \nrequests\nrequests\ndef\ndef\n \nget_weather\n(\napi_key\n,\n \ncity\n):\n    \n"""\n    Fetches t'

# %% [markdown]
# # 2. Split the Text into chunks with chunk size of 100 and overlap of 200

# %%
# We need to split the text that we read into smaller chunks so that during information retreival we don't hit the token size limits.
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator = "\n",
    chunk_size = 500,
    chunk_overlap  = 200,
    length_function = len,
)
texts = text_splitter.split_text(raw_text)

len(texts)
# Out:
# 5

# %%
texts[0]
# Out:
# 'import\nimport\n \nrequests\nrequests\ndef\ndef\n \nget_weather\n(\napi_key\n,\n \ncity\n):\n    \n"""\n    Fetches the current weather data for the specified city using OpenWeatherMap API.\n    Parameters:\n    - api_key (str): Your API key for OpenWeatherMap.\n    - city (str): The city name for which weather data is to be fetched.\n    Returns:\n    - dict: A dictionary containing weather data if successful, None otherwise.\n    """\n    \nurl\n \n=\n \nf\n"http://api.openweathermap.org/data/2.5/weather?q={city}&appid='

# %% [markdown]
# # 3. Setting up HuggingFace Environment

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "HUGGINGFACEHUB_API_TOKEN"

# %% [markdown]
# # 4. Convert chunks into Embeddings

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from sentence_transformers import SentenceTransformer

embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda122.so
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching in backup paths...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 122
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda122.so...
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: /usr/lib64-nvidia did not contain ['libcudart.so', 'libcudart.so.11.0', 'libcudart.so.12.0'] as expected! Searching further paths...
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('http'), PosixPath('8013'), PosixPath('//172.28.0.1')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/gpu-t4-s-5tjlnc67vxi9 --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true'), PosixPath('--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/env/python')}
#   warn(msg)
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py:149: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//ipykernel.pylab.backend_inline'), PosixPath('module')}
#   warn(msg)
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Instantiate the SentenceTransformer model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Generate embeddings for all texts
embedding_vectors = np.array([model.encode(text) for text in texts])

# Create a FAISS index - the size of the vectors determines the dimension
dimension = embedding_vectors.shape[1]
faiss_index = faiss.IndexFlatL2(dimension)

# Add embeddings to the FAISS index
faiss_index.add(embedding_vectors.astype(np.float32))

# %%
class Document:
    def __init__(self, page_content, metadata=None):
        self.page_content = page_content
        self.metadata = metadata if metadata is not None else {}

def retrive_context(query):
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
    query_vector = model.encode(query)

    k=5
    distances, indices = faiss_index.search(np.array([query_vector]).astype(np.float32), k)


    retrieved_text=[]

    for i, idx in enumerate(indices[0]):
        retrieved_text.append(texts[idx])

    return retrieved_text

def retrieve_and_format_documents(query):
    retrieved_text = retrive_context(query)
    formatted_documents = [Document(page_content=text) for text in retrieved_text]

    return formatted_documents

# %%
from langchain.llms import LlamaCpp
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from huggingface_hub import hf_hub_download
from langchain.chains.question_answering import load_qa_chain

# %% [markdown]
# Llama

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, you need an access token
hf_auth = "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"
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)

# enable evaluation mode to allow model inference
model.eval()

print(f"Model loaded on {device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/configuration_auto.py:913: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:468: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# You are calling `save_pretrained` to a 4-bit converted model, but your `bitsandbytes` version doesn't support it. If you want to save 4-bit models, make sure to have `bitsandbytes>=0.41.3` installed.
# Model loaded on cuda:0

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:757: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
stop_list = ['\nHuman:', '\n```\n']

stop_token_ids = [tokenizer(x)['input_ids'] for x in stop_list]
stop_token_ids
# Out:
# [[1, 29871, 13, 29950, 7889, 29901], [1, 29871, 13, 28956, 13]]

# %%
import torch

stop_token_ids = [torch.LongTensor(x).to(device) for x in stop_token_ids]
stop_token_ids
# Out:
# [tensor([    1, 29871,    13, 29950,  7889, 29901], device='cuda:0'),
#  tensor([    1, 29871,    13, 28956,    13], device='cuda:0')]

# %%
from transformers import StoppingCriteria, StoppingCriteriaList

# define custom stopping criteria object
class StopOnTokens(StoppingCriteria):
    def __call__(self, input_ids: torch.LongTensor, scores: torch.FloatTensor, **kwargs) -> bool:
        for stop_ids in stop_token_ids:
            if torch.eq(input_ids[0][-len(stop_ids):], stop_ids).all():
                return True
        return False

stopping_criteria = StoppingCriteriaList([StopOnTokens()])

# %%
generate_text = transformers.pipeline(
    model=model,
    tokenizer=tokenizer,
    #return_full_text=True,  # langchain expects the full text
    task='text-generation',
    # we pass model parameters here too
    #stopping_criteria=stopping_criteria,  # without this model rambles during chat
    temperature=0.1,  # 'randomness' of outputs, 0.0 is the min and 1.0 the max
    max_new_tokens=1024,  # max number of tokens to generate in the output
    repetition_penalty=1.1  # without this output begins repeating
)

# %%
from langchain.llms import HuggingFacePipeline

llm_llama= HuggingFacePipeline(pipeline=generate_text)
chain=load_qa_chain(llm_llama, chain_type="stuff")

# %% [markdown]
# ## Conversation based on the Code File's Context

# %%
import textwrap

query="What does this code do?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  This code defines a Python function named `get_weather` that retrieves the current weather data for a given city using
# the OpenWeatherMap API. It takes two input parameters: `api_key` and `city`, and returns a dictionary containing weather
# data if successful, or `None` otherwise. The function first prompts the user to enter their OpenWeatherMap API key and
# the city name, then makes an HTTP request to the OpenWeatherMap API to retrieve the weather data. If the response is
# valid JSON data, it parses the data and returns a dictionary containing the temperature, weather description, and
# humidity. Otherwise, it raises an `HTTPError`.

# %%
query="What does the get_weather function do? What parameters does it require? What does it return?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  The get_weather function retrieves current weather data for a given city using the OpenWeatherMap API. It requires two
# parameters: api_key and city, and returns a dictionary containing weather data if successful, or None otherwise. The
# function first checks if the input city is valid, then makes a GET request to the OpenWeatherMap API with the provided
# api_key and city name. It then parses the JSON response to extract the temperature, weather, and humidity information.
# Finally, it returns a dictionary containing these values.

# %%
query="Explain how the response.raise_for_status() method works in the context of this script. What exceptions might be raised by this method?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  In the context of this script, response.raise_for_status() is used to handle HTTP errors that might occur when fetching
# weather data from OpenWeatherMap API. When this method is called, it checks the status code of the response and raises
# an HTTPError exception if the status code is not 200 (OK). Additionally, it also catches any other exceptions that might
# be raised by the request, such as a RequestException. Therefore, the method can potentially raise two types of
# exceptions:  1. HTTPError: This exception is raised if the status code of the response is not 200 (OK). 2.
# RequestException: This exception is caught by the method if any other exception is raised by the request.  In summary,
# response.raise_for_status() is used to handle HTTP errors and other exceptions that might occur during the request, and
# it can potentially raise two types of exceptions: HTTPError and RequestException.

# %%
query="How does the script handle JSON responses? How does it extract specific data (like temperature, weather description, and humidity) from the JSON response?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  The script uses Python's built-in `json` module to parse the JSON response from the OpenWeatherMap API. It then
# iterates over the response object and extracts the desired data using the square bracket notation (`[]`). For example,
# to extract the temperature value, the script uses `data['main']['temp']`. Similarly, to extract the weather description,
# it uses `data['weather'][0]['description']`.

# %%
query="What improvements could be made to the get_weather function to handle more detailed weather data? For example, how could you modify it to include wind speed and direction?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  To handle more detailed weather data, such as wind speed and direction, you could modify the get_weather function to
# send a more detailed request to the OpenWeatherMap API. Instead of just sending a request for the current temperature,
# you could send a request for the full weather forecast, including wind speed and direction. This would require modifying
# the URL of the requests.get() method to include additional parameters for the requested data. For example, you could use
# the following URL format: ``` url =
# f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric&forecast=true" ``` This would
# return a JSON object containing the full weather forecast, including wind speed and direction. You could then parse this
# JSON object and extract the desired information, such as wind speed and direction, and display it in the output. ```
# weather_data = response.json() wind_speed = weather_data['wind']['speed'] wind_direction =
# weather_data['wind']['direction'] print(f"Wind Speed: {wind_speed} km/h") print(f"Wind Direction: {wind_direction}
# degrees") ``` Alternatively, you could use the OpenWeatherMap API's `weather_forecast` endpoint, which provides a more
# detailed forecast, including wind speed and direction. This would require modifying the URL of the requests.get() method
# to include the `weather_forecast` parameter. For example: ``` url =
# f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric&weather_forecast=true" ``` This
# would return a JSON object containing the full weather forecast, including wind speed and direction. You could then
# parse this JSON object and extract the desired information, such as wind speed and direction, and display it in the
# output. ``` weather_data = response.json() wind_speed = weather_data['weather_forecast'][0]['wind']['speed']
# wind_direction = weather_data['weather_forecast'][0]['wind']['direction'] print(f"Wind Speed: {wind_speed} km/h")
# print(f"Wind Direction: {wind_direction} degrees") ``` By making these modifications, you can retrieve more detailed
# weather data, including wind speed and direction, from the OpenWeatherMap API.

# %%
query="Discuss the error handling in this script. Is there any scenario where the error handling might fail to catch an error? How could you improve the error handling to cover more failure scenarios?"
answer = chain.run(input_documents=retrieve_and_format_documents(query), question=query)
wrapped_answer = textwrap.fill(answer, width=120)
print(f"\nAnswer: {wrapped_answer}")
# Out:
# Answer:  In this script, the error handling is limited to catching HTTP errors and raising them as exceptions. However, there
# are other types of errors that might occur during the execution of the script, such as invalid input parameters, network
# connectivity issues, or server-side errors. To improve the error handling, you could consider adding additional error
# handling mechanisms, such as:  1. Validating input parameters: You could add validation checks for the input parameters,
# such as checking if the API key is provided, or ensuring that the city name is valid. 2. Handling network connectivity
# issues: You could add retry mechanisms to handle network connectivity issues, such as retries after a certain delay or
# using alternative networks. 3. Catching server-side errors: You could add additional exception handlers to catch server-
# side errors, such as HTTP status codes beyond 400, and raise appropriate errors based on the severity of the issue. 4.
# Providing more detailed error messages: You could provide more detailed error messages to help the user identify and
# resolve the issue, such as the specific error message from the server or the request ID. By implementing these
# additional error handling mechanisms, you can improve the robustness of the script and reduce the likelihood of errors
# going undetected.
